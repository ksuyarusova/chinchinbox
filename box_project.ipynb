# %% [markdown]
# <a href="https://colab.research.google.com/github/ksuyarusova/chinchinbox/blob/master/box_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyTelegramBotAPI #--no-cache-dir
# Out:
# ...
#     100% |████████████████████████████████| 51kB 3.3MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/ae/69/d7/26f1fb04ac4d4c95bff643cea765a8e91c4348da25b4744e08
# Successfully built pyTelegramBotAPI
# ...

# %%
import telebot

access_token = '706146243:AAFRyLQpHcgQ7i4DjfvTCYNRkK__WhOurhw'
# Создание бота с указанным токеном доступа
bot = telebot.TeleBot(access_token)#, threaded = False)
#telebot.apihelper.proxy = {'https':'socks5://13.81.169.254:1080'}

# %%
print(bot.get_me())
# Out:
# {'id': 706146243, 'is_bot': True, 'first_name': 'chinchinboxes', 'username': 'chinchinbox_bot', 'last_name': None, 'language_code': None}

# %%
@bot.message_handler(content_types=['text'])
def echo(message):
    bot.send_message(message.chat.id, message.text)


if __name__ == '__main__':
    bot.polling(none_stop=True)

# %%
import requests
def send_stats(mess):
    r2 = requests.get('https://api.telegram.org/bot{}/sendMessage?chat_id={}&text={}'.format(access_token, '244350320', mess))


bot = telebot.TeleBot(access_token, threaded = False)

#  С клавой
# @bot.message_handler(commands = ['create_box'])
# def createbox(message):
#       keyboard1 = telebot.types.ReplyKeyboardMarkup(one_time_keyboard = False)
#       keyboard1.row('\U0001F332 Новый год')
#       keyboard1.row('\U0001F381 ДР')
#       bot.send_message(message.chat.id, '*Для какого события Вы подбираете подарок?*', reply_markup = keyboard1, parse_mode = 'markdown')
# @bot.message_handler(func = lambda message: message.text == '\U0001F332 *Новый год*')  


# ловим события      
@bot.message_handler(commands = ['create_box','start'])  
def createbox(message):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Новый Год \U0001F384', callback_data = 'newyear'))
    keyboard1.row(telebot.types.InlineKeyboardButton('День Рождения \U0001F381', callback_data = 'birthday'))
    keyboard1.row(telebot.types.InlineKeyboardButton('День Святого Валентина \U0001F496', callback_data = 'loveday'))
    keyboard1.row(telebot.types.InlineKeyboardButton('8 Марта \U0001F338', callback_data = 'womanday'))
    keyboard1.row(telebot.types.InlineKeyboardButton('23 Февраля \U0001F46E', callback_data = 'manday'))
    create1 = bot.send_message(message.chat.id, '*Для какого события Вы подбираете подарок?*', reply_markup = keyboard1, parse_mode = 'markdown')

    
# # после НГ ловим второй вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'newyear')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Большая', callback_data = 'ng_big'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Средняя', callback_data = 'ng_med'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Маленькая', callback_data = 'ng_small'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384 \n\nКакого размера коробку Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')
 

# после НГ и большой коробки ловим 3 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'ng_big')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweet'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toy'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beauty'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcohol'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothes'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'home'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')

       
# после НГ, большой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweet')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'yes'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'no'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после НГ, большой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'yes')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    photo = 'http://i67.tinypic.com/2w7r48h.jpg'
    bot.send_photo(query.message.chat.id, photo)
    send_stats('sweet_yes\n' +  str(query.message.chat.id))
    
# после НГ, большой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'no')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    send_stats('sweet_no')
      
# после НГ, большой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toy')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'a'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'b'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, большой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'a')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, большой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'b')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после НГ, большой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beauty')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'c'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'd'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, большой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'c')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, большой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'd')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, большой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcohol')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'e'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'f'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после НГ, большой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'e')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, большой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'f')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после НГ, большой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothes')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'g'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'h'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, большой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'g')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, большой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'h')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, большой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'home')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'i'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'k'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, большой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'i')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, большой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'k')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после НГ и средней коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'ng_med')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweety'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyy'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyy'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholy'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesy'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homey'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')


# после НГ, средней, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweety')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'l'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'm'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после НГ, средней коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'l')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, средней коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'm')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
     
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')   
      
# после НГ, средней коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyy')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'n'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'o'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, средней коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'n')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSNAtUH9ND/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    photo = 'http://i64.tinypic.com/2i886f7.jpg'
    bot.send_photo(query.message.chat.id, photo)
    
# после НГ, средней коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'o')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, средней коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyy')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'p'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'q'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, средней коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'p')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, средней коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'q')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, средней коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholy')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'r'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 's'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после НГ, средней коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'r')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, средней коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 's')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после НГ, средней коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesy')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 't'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'u'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, средней коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 't')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, средней коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'u')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, средней коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homey')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'v'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'w'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, средней коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'v')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, средней коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'w')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ и маленькой коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'ng_small')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweeta'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toya'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautya'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcohola'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesa'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homea'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')    

    
# после НГ, маленькой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweeta')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'x'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'y'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после НГ, маленькой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'x')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'y')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
      
# после НГ, маленькой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toya')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'z'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aa'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, маленькой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'z')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aa')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautya')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'bb'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'cc'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, маленькой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'bb')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'cc')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcohola')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'dd'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ee'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после НГ, маленькой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'dd')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ee')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после НГ, маленькой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesa')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ff'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'gg'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, маленькой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ff')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'gg')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homea')
def newyear(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'hh'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ii'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после НГ, маленькой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'hh')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после НГ, маленькой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ii')
def newyear(query):
    finalvars = ['1 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на Новый год* \U0001F384\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
        
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 

    
    
    
    
    
    


#     keyboard1 = telebot.types.InlineKeyboardMarkup()
#     keyboard1.row(telebot.types.InlineKeyboardButton('Получить открытку', callback_data = 'final'))
#     bot.edit_message_text(chat_id = query.message.chat.id, 
#                           message_id = query.message.message_id,
#                           text = '\U0001F384 *Подарок на Новый год*\n*Размер*: Большая\n\nВот ваши коробки', parse_mode = 'markdown')
#     for text in finalvars:
#         bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')

  
# # после ДР ловим второй вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'birthday')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Большая', callback_data = 'dr_big'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Средняя', callback_data = 'dr_med'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Маленькая', callback_data = 'dr_small'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n\nКакого размера коробку Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')

# после ДР и большой коробки ловим 3 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'dr_big')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweete'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toye'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautye'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcohole'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothese'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homee'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')

       
# после ДР, большой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweete')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'kk'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'll'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ДР, большой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'kk')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    
# после ДР, большой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'll')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    
      
# после ДР, большой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toye')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'mm'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'nn'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, большой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'mm')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, большой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'nn')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после ДР, большой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautye')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'oo'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'pp'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, большой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'oo')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, большой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'pp')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, большой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcohole')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'rr'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ss'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ДР, большой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'rr')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, большой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ss')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ДР, большой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothese')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'tt'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'uu'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, большой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'tt')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, большой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'uu')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, большой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homee')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'qq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'vv'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, большой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'qq')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, большой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'vv')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после ДР и средней коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'dr_med')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homeu'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')


# после ДР, средней, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetu')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ww'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'xx'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ДР, средней коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ww')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'xx')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
     
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')   
      
# после ДР, средней коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyu')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'yy'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'zz'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, средней коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'yy')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'zz')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyu')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aaa'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'bbb'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, средней коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aaa')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'bbb')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholu')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccc'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ddd'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ДР, средней коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccc')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ddd')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ДР, средней коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesu')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'eee'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'fff'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, средней коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'eee')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'fff')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homeu')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ggg'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'hhh'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, средней коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ggg')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, средней коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'hhh')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР и маленькой коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'dr_small')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweeti'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyi'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyi'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholi'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesi'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homei'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')    

    
# после ДР, маленькой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweeti')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'iii'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'kkk'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ДР, маленькой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'iii')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'kkk')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
      
# после ДР, маленькой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyi')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'lll'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'mmm'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, маленькой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'lll')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'mmm')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyi')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'nnn'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ooo'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, маленькой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'nnn')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ooo')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholi')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ppp'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'qqq'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ДР, маленькой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ppp')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'qqq')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ДР, маленькой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesi')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'rrr'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'sss'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, маленькой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'rrr')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'sss')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homei')
def birthday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ttt'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'uuu'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДР, маленькой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ttt')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДР, маленькой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'uuu')
def birthday(query):
    finalvars = ['1 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День рождения* \U0001F381\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
        
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')     
    
 


    
    
    
# после ДСВ ловим второй вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'loveday')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Большая', callback_data = 'dsv_big'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Средняя', callback_data = 'dsv_med'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Маленькая', callback_data = 'dsv_small'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n\nКакого размера коробку Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')

# после ДСВ и большой коробки ловим 3 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'dsv_big')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweeto'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyo'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyo'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholo'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clotheso'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homeo'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')

       
# после ДСВ, большой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweeto')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'qqqq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'wwww'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ДСВ, большой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'qqqq')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    
# после ДСВ, большой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'wwww')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    
      
# после ДСВ, большой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyo')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'eeee'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'rrrr'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, большой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'eeee')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, большой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'rrrr')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после ДСВ, большой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyo')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'tttt'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'yyyy'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, большой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'tttt')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, большой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'yyyy')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, большой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholo')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'uuuu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'iiii'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ДСВ, большой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'uuuu')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, большой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'iiii')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ДСВ, большой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clotheso')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'oooo'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'pppp'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, большой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'oooo')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, большой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'pppp')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, большой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homeo')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aaaa'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ssss'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, большой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aaaa')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, большой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ssss')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после ДСВ и средней коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'dsv_med')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homeq'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')


# после ДСВ, средней, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetq')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'dddd'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ffff'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ДСВ, средней коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'dddd')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ffff')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
     
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')   
      
# после ДСВ, средней коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyq')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'gggg'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'hhhh'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, средней коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'gggg')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'hhhh')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyq')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'jjjj'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'kkkk'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, средней коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'jjjj')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'kkkk')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholq')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'llll'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'zzzz'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ДСВ, средней коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'llll')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'zzzz')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ДСВ, средней коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesq')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'xxxx'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'cccc'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, средней коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'xxxx')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'cccc')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homeq')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'vvvv'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'bbbb'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, средней коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'vvvv')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, средней коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'bbbb')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ и маленькой коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'dsv_small')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetw'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyw'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyw'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholw'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesw'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homew'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')    

    
# после ДСВ, маленькой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetw')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'nnnn'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'mmmm'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ДСВ, маленькой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'nnnn')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'mmmm')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
      
# после ДСВ, маленькой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyw')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'vvv'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'www'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, маленькой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'vvv')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'www')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyw')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'xxx'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'yyy'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, маленькой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'xxx')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'yyy')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholw')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'zzz'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'zzq'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ДСВ, маленькой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'zzz')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'zzq')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ДСВ, маленькой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesw')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'qqw'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'qqe'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, маленькой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'qqw')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'qqe')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homew')
def loveday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'qqr'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'qqt'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ДСВ, маленькой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'qqr')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ДСВ, маленькой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'qqt')
def loveday(query):
    finalvars = ['1 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на День Святого Валентина* \U0001F496\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
        
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')     
    
    
    
    
    
# после ЖД ловим второй вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'womanday')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Большая', callback_data = 'wd_big'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Средняя', callback_data = 'wd_med'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Маленькая', callback_data = 'wd_small'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n\nКакого размера коробку Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')

# после ЖД и большой коробки ловим 3 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'wd_big')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetz'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyz'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyz'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholz'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesz'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homez'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')

       
# после ЖД, большой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetz')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aas'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aad'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ЖД, большой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aas')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    
# после ЖД, большой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aad')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    
      
# после ЖД, большой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyz')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aaq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aaw'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, большой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aaq')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, большой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aaw')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после ЖД, большой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyz')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aaf'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aag'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, большой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aaf')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, большой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aag')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, большой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholz')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aaz'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aax'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ЖД, большой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aaz')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, большой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aax')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ЖД, большой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesz')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aae'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aar'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, большой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aae')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, большой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aar')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, большой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homez')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aah'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aaj'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, большой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aah')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, большой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aaj')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после ЖД и средней коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'wd_med')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetf'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyf'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyf'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholf'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesf'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homef'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')


# после ЖД, средней, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetf')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aac'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aav'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ЖД, средней коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aac')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aav')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
     
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')   
      
# после ЖД, средней коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyf')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aat'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aay'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, средней коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aat')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aay')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyf')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aak'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aal'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, средней коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aak')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aal')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholf')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aau'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aai'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ЖД, средней коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aau')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aai')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ЖД, средней коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesf')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aao'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aap'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, средней коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aao')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aap')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homef')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'aab'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'aan'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, средней коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'aab')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, средней коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'aan')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД и маленькой коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'wd_small')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetc'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyc'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyc'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholc'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesc'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homec'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')    

    
# после ЖД, маленькой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetc')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ssq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ssw'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после ЖД, маленькой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ssq')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, маленькой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ssw')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
      
# после ЖД, маленькой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyc')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'sse'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ssr'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, маленькой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'sse')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, маленькой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ssr')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, маленькой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyc')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'sst'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ssy'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, маленькой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'sst')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    photo = 'http://i63.tinypic.com/732wyg.jpg'
    bot.send_photo(query.message.chat.id, photo)
    
# после ЖД, маленькой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ssy')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, маленькой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholc')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ssu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ssi'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после ЖД, маленькой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ssu')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, маленькой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ssi')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после ЖД, маленькой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesc')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'sso'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ssp'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, маленькой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'sso')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, маленькой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ssp')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, маленькой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homec')
def womanday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ssd'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ssf'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после ЖД, маленькой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ssd')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после ЖД, маленькой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ssf')
def womanday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
        
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')     
    
    
    
    
    
# после МД ловим второй вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'manday')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Большая', callback_data = 'md_big'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Средняя', callback_data = 'md_med'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Маленькая', callback_data = 'md_small'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n\nКакого размера коробку Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')
    
# после МД и большой коробки ловим 3 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'md_big')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetl'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyz'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyl'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholl'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesl'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homel'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')

       
# после МД, большой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetl')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccw'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после МД, большой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccq')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    
# после МД, большой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccw')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')    
    
      
# после МД, большой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyl')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'cce'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccr'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, большой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'cce')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, большой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccr')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после МД, большой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyl')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'cct'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccy'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, большой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'cct')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, большой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccy')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, большой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholl')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'cci'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после МД, большой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccu')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, большой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'cci')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после МД, большой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesl')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'cco'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccp'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, большой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'cco')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, большой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccp')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, большой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homel')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'cca'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccs'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, большой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'cca')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, большой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccs')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Большая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
    
# после МД и средней коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'md_med')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetk'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyf'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyk'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholk'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesk'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homek'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')


# после МД, средней, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetk')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccd'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccf'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после МД, средней коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccd')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccf')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
     
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')   
      
# после МД, средней коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyk')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccg'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'cch'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, средней коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccg')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'cch')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyk')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccj'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'cck'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, средней коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccj')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'cck')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholk')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccl'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccz'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после МД, средней коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccl')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccz')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после МД, средней коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesk')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccv'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccb'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, средней коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccv')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccb')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n**Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homek')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'ccn'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'ccm'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, средней коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'ccn')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, средней коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'ccm')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Средняя\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД и маленькой коробки ловим 3 вопрос
@bot.callback_query_handler(func = lambda call: call.data == 'md_small')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Со сладостями', callback_data = 'sweetj'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С мягкой игрушкой', callback_data = 'toyc'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С косметическими средствами', callback_data = 'beautyj'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С алкоголем', callback_data = 'alcoholj'))
    keyboard1.row(telebot.types.InlineKeyboardButton('С одеждой', callback_data = 'clothesj'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Для дома', callback_data = 'homej'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n\nКакой тип содержимого коробки Вы рассматриваете?', reply_markup = keyboard1, parse_mode = 'markdown')    

    
# после МД, маленькой коробки, типа со сладостями ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'sweetj')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'vvq'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'vvw'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')     

# после МД, маленькой коробки, типа со сладостями, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'vvq')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа со сладостями, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'vvw')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Со сладостями\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
      
# после МД, маленькой коробки, типа с игрушкой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'toyj')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'vve'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'vvr'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С мягкой игрушкой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, маленькой коробки, типа с игрушкой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'vve')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа с игрушкой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'vvr')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С игрушкой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']
 
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа с косметикой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'beautyj')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'vvt'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'vvy'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С косметическими средствами\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, маленькой коробки, типа с косметикой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'vvt')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа с косметикой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'vvy')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 8 Марта* \U0001F338\n*Размер*: Маленькая\n*Тип бокса*: С косметикой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']    

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа с алкоголем ловим 4 вопрос  
@bot.callback_query_handler(func = lambda call: call.data == 'alcoholj')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'vvu'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'vvi'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')       

# после МД, маленькой коробки, типа с алкоголем, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'vvu')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа с алкоголем, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'vvi')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С алкоголем\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
  
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
  
# после МД, маленькой коробки, типа с одеждой ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'clothesj')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'vvo'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'vvp'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, маленькой коробки, типа с одеждой, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'vvo')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа с одеждой, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'vvp')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: С одеждой\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']        
    
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа для дома ловим 4 вопрос    
@bot.callback_query_handler(func = lambda call: call.data == 'homej')
def manday(query):
    keyboard1 = telebot.types.InlineKeyboardMarkup()
    keyboard1.row(telebot.types.InlineKeyboardButton('Да', callback_data = 'vvd'))
    keyboard1.row(telebot.types.InlineKeyboardButton('Нет', callback_data = 'vvf'))
    bot.edit_message_text(chat_id = query.message.chat.id, 
                          message_id = query.message.message_id,
                          text = '*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n\nХотели бы Вы вложить в коробку открытку?', reply_markup = keyboard1, parse_mode = 'markdown')        

# после МД, маленькой коробки, типа для дома, наличия открытки ловим варианты боксов  
@bot.callback_query_handler(func = lambda call: call.data == 'vvd')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-MFzMHJA1/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/BrSI9SonKRF/)']

    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown') 
    
# после МД, маленькой коробки, типа для дома, отсутствия открытки ловим варианты боксов    
@bot.callback_query_handler(func = lambda call: call.data == 'vvf')
def manday(query):
    finalvars = ['1 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-ILqAHEfR/)',
                 '2 вариант\n*Подарок на 23 февраля* \U0001F46E\n*Размер*: Маленькая\n*Тип бокса*: Для дома\n[*ПОДРОБНЕЕ*](https://www.instagram.com/p/Bq-Fx6jn9t1/)']  
        
    for text in finalvars:
        bot.send_message(query.message.chat.id, text, parse_mode = 'markdown')
